# %% [markdown]
# <a href="https://colab.research.google.com/github/kdemertzis/EKPA/blob/main/dga_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# εγκατάσταση πακέτου pycaret (https://pycaret.org/)
# !pip install pycaret
# ***ΠΡΟΣΟΧΗ*** μετά την εγκατάσταση χρειάζεται restart το session
# ***θα σας ζητηθεί επανεκκίνηση με σχετικό κόκκινο μήνυμα μετά την ολοκλήρωση της εγκατάστασης
# ***Πατήστε το κουμπί RESTART SESSION στο σχετικό μήνυμα
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pycaret in c:\users\as\appdata\roaming\python\python311\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (9.7.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (8.1.8)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (2.0.5)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (0.62.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (2.32.5)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (7.1.3)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (6.4.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (0.14.5)
# Requirement already satisfied: sktime==0.26.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\as\appdata\roaming\python\python311\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\as\appdata\roaming\python\python311\site-packages (from sktime==0.26.0->pycaret) (25.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\as\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (1.4.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\as\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from scikit-learn>1.4.0->pycaret) (3.6.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\as\appdata\roaming\python\python311\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\as\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.14)
# Requirement already satisfied: comm>=0.1.3 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\as\appdata\roaming\python\python311\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\as\appdata\roaming\python\python311\site-packages (from jedi>=0.18.1->ipython>=5.5.0->pycaret) (0.8.5)
# Requirement already satisfied: choreographer>=1.1.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from kaleido>=0.2.1->pycaret) (1.2.0)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\as\appdata\roaming\python\python311\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\as\appdata\roaming\python\python311\site-packages (from kaleido>=0.2.1->pycaret) (3.11.4)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\as\appdata\roaming\python\python311\site-packages (from choreographer>=1.1.1->kaleido>=0.2.1->pycaret) (3.20.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\as\appdata\roaming\python\python311\site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\as\appdata\roaming\python\python311\site-packages (from nbformat>=4.2.0->pycaret) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\as\appdata\roaming\python\python311\site-packages (from nbformat>=4.2.0->pycaret) (5.9.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\as\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\as\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\as\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.5.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\as\appdata\roaming\python\python311\site-packages (from numba>=0.55.0->pycaret) (0.45.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from plotly>=5.14.0->pycaret) (2.10.2)
# Requirement already satisfied: dash>=2.11.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.2.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\as\appdata\roaming\python\python311\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\as\appdata\roaming\python\python311\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\as\appdata\roaming\python\python311\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: retrying in c:\users\as\appdata\roaming\python\python311\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\as\appdata\roaming\python\python311\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (65.5.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\as\appdata\roaming\python\python311\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\as\appdata\roaming\python\python311\site-packages (from pmdarima>=2.0.4->pycaret) (3.2.0)
# Requirement already satisfied: urllib3 in c:\users\as\appdata\roaming\python\python311\site-packages (from pmdarima>=2.0.4->pycaret) (2.5.0)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (9.0.0)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\as\appdata\roaming\python\python311\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\as\appdata\roaming\python\python311\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\as\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\as\appdata\roaming\python\python311\site-packages (from requests>=2.27.1->pycaret) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\as\appdata\roaming\python\python311\site-packages (from requests>=2.27.1->pycaret) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\as\appdata\roaming\python\python311\site-packages (from requests>=2.27.1->pycaret) (2025.10.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\as\appdata\roaming\python\python311\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\as\appdata\roaming\python\python311\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (0.2.3)

# %%
# εισαγωγή βιβλιοθηκών - πακέτων
import pycaret
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pycaret.classification import *

# %%
# εισαγωγή του συνόλου δεδομένων
url = 'https://raw.githubusercontent.com/mars600/l3594-c1-u2/refs/heads/main/data/dga_domain.csv'
df = pd.read_csv(url)
# έλεγχος σχήματος συνόλου δεδομένων
print(df.shape)
# Out:
# (117588, 6)

# %%
# ανακάτεμα των δεδομένων
df = df.sample(frac = 1)
print(df.head())
# Out:
#        length   entropy   alexa_grams   word_grams       diff    class
# 42171       7  2.521641     12.966980    27.029262 -14.062282    legit
# 84793       6  2.251629     11.932647    21.161318  -9.228671    legit
# 71919       4  2.000000      1.662758     2.193125  -0.530367  suspect
# 74157       7  2.235926     23.344108    32.602224  -9.258116    legit
# 87044      17  3.219528     57.797528    55.214172   2.583356    legit

# %%
# εγκατάσταση του συνόλου δεδομένων
grid = setup(data=df, target=df.columns[-1], html=False, verbose=False)

# %%
# σύγκριση των διαθέσιμων μοντέλων ΜΜ
best = compare_models(cross_validation=False, n_select = 1)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.8875  0.9095  0.8875  0.8879
# gbc          Gradient Boosting Classifier    0.8869  0.9067  0.8869  0.8871
# rf               Random Forest Classifier    0.8809  0.8957  0.8809  0.8768
# lr                    Logistic Regression    0.8738  0.8752  0.8738  0.8715
# knn                K Neighbors Classifier    0.8731  0.8677  0.8731  0.8681
# et                 Extra Trees Classifier    0.8707  0.8880  0.8707  0.8652
# lda          Linear Discriminant Analysis    0.8492  0.8594  0.8492  0.8531
# ridge                    Ridge Classifier    0.8314  0.0000  0.8314  0.8400
# dt               Decision Tree Classifier    0.8269  0.7857  0.8269  0.8277
# svm                   SVM - Linear Kernel    0.8202  0.0000  0.8202  0.8343
# qda       Quadratic Discriminant Analysis    0.7825  0.8776  0.7825  0.8211
# ada                  Ada Boost Classifier    0.7671  0.5771  0.7671  0.6453
# nb                            Naive Bayes    0.7625  0.7764  0.7625  0.7348
# dummy                    Dummy Classifier    0.7342  0.0000  0.7342  0.5391
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.8786  0.6945  0.7119      0.89
# gbc       0.8777  0.6929  0.7105     38.90
# rf        0.8742  0.6850  0.6940     14.41
# lr        0.8649  0.6592  0.6738      2.49
# knn       0.8663  0.6653  0.6735      0.09
# et        0.8653  0.6639  0.6690      4.23
# lda       0.8364  0.5754  0.6017      0.05
# ridge     0.7977  0.4757  0.5414      0.06
# dt        0.8273  0.5767  0.5767      0.65
# svm       0.8253  0.5837  0.5875      1.91
# qda       0.7929  0.5329  0.5474      0.06
# ada       0.6739  0.2217  0.3345      3.26
# nb        0.7403  0.3579  0.3683      0.04
# dummy     0.6217  0.0000  0.0000      0.04

# %%
# αναφορά των υπερπαραμέτρων του μοντέλου με την υψηλότερη απόδοση
print(best)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=8174, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
# μέτρα αξιολόγησης του μοντέλου με την υψηλότερη απόδοση
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
